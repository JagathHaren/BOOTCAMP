# %% [markdown]
# # 1. Write a function called check() , that takes in a list as the input. It has to return whether every element in it as ‘greater than 5’ or ‘not greater than 5’ or equal to 5. The returned value has to be placed in the list of tuples as (4, 'Less than 5'), (12, 'Greater than 5'), (5, 'Equal to 5'), and so on...

# %%
def check(l):
  nl=[]
  for i in range(len(l)):
    if l[i]>5:
      y="Greater than 5"
    elif l[i]<5:
      y="Lesser than 5"
    else:
      y="Equal to 5"
    x=(l[i],y)
    nl.append(x)
  return nl
l=[2,3,4,5,6,7]
n=check(l)
print(n)
# Out:
# [(2, 'Lesser than 5'), (3, 'Lesser than 5'), (4, 'Lesser than 5'), (5, 'Equal to 5'), (6, 'Greater than 5'), (7, 'Greater than 5')]

# %% [markdown]
# #2. Write a program in Python to produce Star triangle for any number n
# #   *
# #  * *
# # * * *
# #...... for n stars

# %%
n=int(input("Enter n:"))
k = 2*n-2
for i in range(0, n): 
    for j in range(0, k):
      print(end=" ") 
    k = k - 1
    for j in range(0, i+1): 
      print("* ", end="") 
    print("")
# Out:
# Enter n:4
#       *
#      * *
#     * * *
#    * * * *

# %% [markdown]
# #3. Write a program to produce Fibonacci series using generator in Python

# %%
def fib(limit): 
	a, b = 0, 1
	while a < limit: 
		a, b = b, a + b 
	return a
n=int(input("enter n:"))
for i in range(n):
  x=fib(i)
  print(x[-1],end=" ")
# Out:
# enter n:5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-4e411fbe9828> in <module>()
#       7 for i in range(n):
#       8   x=fib(i)
# ----> 9   print(x[-1],end=" ")
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# #4. Write a program to check a number and a string are palindrome or not without using looping statement.

# %%
# function which return reverse of a string

def pal(s):
	return s == s[::-1]
if (pal(input("Enter number or string:"))):
	print("It is a palindrome")
else:
	print("It is not  a palindrome")
# Out:
# Enter number or string:appa
# It is a palindrome

# %% [markdown]
# #5. Convert the following dictionary into two lists of country and medals. Again convert them into list of (country,medals) . Finally convert the list of tuples into dictionary again.
# #golds = {"Italy": 12, "USA": 33, "Brazil": 15, "China": 27, "Spain": 19,"Canada": 22, "Argentina": 8, "England": 29}

# %%
golds = {"Italy": 12, "USA": 33, "Brazil": 15, "China": 27, "Spain": 19,"Canada": 22, "Argentina": 8, "England": 29}
c=[]
m=[]
for i in golds.keys():
  c=i
for i in golds.values():
  m=i
lt = [(c[i], m[i]) for i in range(0, len(c))]
print(lt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-82a12b8c3c9b> in <module>()
#       6 for i in golds.values():
#       7   m=i
# ----> 8 lt = [(c[i], m[i]) for i in range(0, len(c))]
#       9 print(lt)
#
# <ipython-input-58-82a12b8c3c9b> in <listcomp>(.0)
#       6 for i in golds.values():
#       7   m=i
# ----> 8 lt = [(c[i], m[i]) for i in range(0, len(c))]
#       9 print(lt)
#
# TypeError: 'int' object is not subscriptable
